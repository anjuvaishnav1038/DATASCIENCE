# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
data=pd.read_csv('tesla.csv')
data.head()
# Out:
#         Date       Open   High        Low      Close    Volume  Adj Close
# 0  6/29/2010  19.000000  25.00  17.540001  23.889999  18766300  23.889999
# 1  6/30/2010  25.790001  30.42  23.299999  23.830000  17187100  23.830000
# 2   7/1/2010  25.000000  25.92  20.270000  21.959999   8218800  21.959999
# 3   7/2/2010  23.000000  23.10  18.709999  19.200001   5139800  19.200001
# 4   7/6/2010  20.000000  20.00  15.830000  16.110001   6866900  16.110001

# %%
df=pd.DataFrame(data,columns=['Date','Close'])
df.head()
# Out:
#         Date      Close
# 0  6/29/2010  23.889999
# 1  6/30/2010  23.830000
# 2   7/1/2010  21.959999
# 3   7/2/2010  19.200001
# 4   7/6/2010  16.110001

# %%
df.isna().values.any() # is there any null values are present or not ?
# Out:
# False

# %%
data.shape # it will print the entire shape of the dataset
# Out:
# (1692, 7)

# %%
data.info() # information about the whole data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1692 entries, 0 to 1691
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1692 non-null   object
#  1   Open       1692 non-null   float64
#  2   High       1692 non-null   float64
#  3   Low        1692 non-null   float64
#  4   Close      1692 non-null   float64
#  5   Volume     1692 non-null   int64
#  6   Adj Close  1692 non-null   float64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 92.7+ KB

# %%
data.describe() # it will print the statiscal analysis of the dataset
# Out:
#               Open         High          Low        Close        Volume  \
# count  1692.000000  1692.000000  1692.000000  1692.000000  1.692000e+03
# mean    132.441572   134.769698   129.996223   132.428658  4.270741e+06
# std      94.309923    95.694914    92.855227    94.313187  4.295971e+06
# min      16.139999    16.629999    14.980000    15.800000  1.185000e+05
# 25%      30.000000    30.650000    29.214999    29.884999  1.194350e+06
# 50%     156.334999   162.370002   153.150002   158.160004  3.180700e+06
# 75%     220.557495   224.099999   217.119999   220.022503  5.662100e+06
# max     287.670013   291.420013   280.399994   286.040009  3.716390e+07
#
#          Adj Close
# count  1692.000000
# mean    132.428658
# std      94.313187
# min      15.800000
# 25%      29.884999
# 50%     158.160004
# 75%     220.022503
# max     286.040009

# %%
plt.rcParams['figure.figsize']=(18,6)
data.plot('Date','Close',color='red') # full data 
new_data=data.head(100)
new_data.plot('Date','Close',color='blue') # 100 data
plt.show()

# %%
plt.rcParams['figure.figsize']=(18,6)
plt.plot(range(data.shape[0]),(data['High']+data['Low'])/2.0)
plt.xticks(range(0,data.shape[0],600),data['Date'].loc[::600],rotation=45)
plt.xlabel('Date',fontsize='18')
plt.ylabel('Mid Price',fontsize=18)
plt.show()

# %%
from sklearn.model_selection import train_test_split
train, test = train_test_split(df, test_size=0.20,random_state=0)
# testing potion would be 20% and training portion would be 80%

# %%
from sklearn.linear_model import LinearRegression
X_train = np.array(train.index).reshape(-1, 1) #features 
#-1,1 means multiple rows and 1 column whereas -1 indicates multiple rows and 1 indicates one 1 column
print(X_train.shape)
y_train = train['Close'] #target

# x_train and y_train 
# x_train,x_test
# y_train,y_test
# where x_train and y_train will be for your training data
# Out:
# (1353, 1)

# %%
model=LinearRegression() # model creation
model.fit(X_train,y_train) # training the model
# Out:
# LinearRegression()

# %%
print("Slope",model.coef_)#means with 1 unit increase in the date the closing price increases by 0.17$
print("Intercept",model.intercept_) # intercept value 
# y=mx+c
# y is dependent data 
# m is slope, tan theta
# x is independent data
# c is the intercept value
# Out:
# Slope [0.17146927]
# Intercept -12.924881261445165

# %%
pred=model.predict(X_train)
print(pred)
# Out:
# [155.1150001   -9.15255739 203.12639478 ... 270.51381659  82.92643882
#  104.36009716]

# %%
plt.rcParams['figure.figsize']=(18,6)
plt.title('Linear Regression Price and Date')
plt.scatter(X_train,y_train,label='Actual Price')
plt.plot(X_train,pred,color='r',label='Predicted Price')
plt.show()

# %%
X_test = np.array(test.index).reshape(-1, 1)
y_test = test['Close'] # target, actual value 
y_pred = model.predict(X_test) # predicted value

# %%
df.shape
# Out:
# (1692, 2)

# %%
df_sample=pd.DataFrame({'Date':test['Date'],'Actual':y_test,'Prediction':y_pred,'Error':(y_test-y_pred)}).head(20)
df_sample
# actual value - predicted value
# Out:
#             Date      Actual  Prediction      Error
# 124   12/23/2010   30.090000    8.337308  21.752692
# 1688   3/14/2017  258.000000  276.515241 -18.515241
# 1397   1/15/2016  204.990005  226.617684 -21.627679
# 6       7/8/2010   17.459999  -11.896066  29.356065
# 1279   7/29/2015  263.820007  206.384311  57.435696
# 642    1/16/2013   34.099998   97.158388 -63.058390
# 229    5/25/2011   28.980000   26.341581   2.638419
# 446     4/4/2012   35.000000   63.550412 -28.550412
# 568    9/27/2012   28.490000   84.469662 -55.979662
# 1110  11/24/2014  246.720001  177.406005  69.313996
# 996    6/13/2014  206.419998  157.858508  48.561490
# 891    1/13/2014  139.339996  139.854235  -0.514239
# 1628  12/14/2016  198.690002  266.227085 -67.537083
# 1608  11/15/2016  183.770004  262.797700 -79.027696
# 1505   6/21/2016  219.610001  245.136365 -25.526364
# 1281   7/31/2015  266.149994  206.727249  59.422745
# 692     4/1/2013   43.930000  105.731851 -61.801851
# 646    1/23/2013   36.000000   97.844265 -61.844265
# 1014   7/10/2014  219.460007  160.944955  58.515052
# 1129  12/22/2014  222.600006  180.663921  41.936085

# %%
fig, ax = plt.subplots()
df_sample.plot(x='Date', y=['Actual', 'Prediction'], kind='bar', ax=ax)
plt.title('Comparison Predicted vs Actual Price in Sample data selection', fontsize=16)
plt.xlabel('Date', fontsize=14)
plt.ylabel('Stock Price in $', fontsize=14)
plt.show()

# %%
plt.figure(1, figsize=(16,10))
plt.title('Price vs Date')
plt.plot(X_test, model.predict(X_test), color='r', label='Predicted Price')
plt.scatter(X_test, y_test, label='Actual Price')

# %%
from sklearn.metrics import explained_variance_score
#It shows that how much variation in Y is explained by the variable X. 
#For example if your r-squared is 0.86, it says that 86% of the variation in Y can be explained by X,
#while the rest is explained by some other variables not included in the model. 
#Its used as a measure of goodness of fit of the model.
explained_variance_score(y_test, y_pred) # actual data, predicted data
# Out:
# 0.7909527409555444

# %%
from sklearn.ensemble import RandomForestRegressor
 
 # create regressor object
regressor = RandomForestRegressor(n_estimators = 100, random_state = 0)
 
# fit the regressor with x and y data
regressor.fit(X_train,y_train)
# Out:
# RandomForestRegressor(random_state=0)

# %%